# %% [markdown]
# <a href="https://colab.research.google.com/github/AYurov28/AYurov28.github.io/blob/main/kandinsky2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install 'git+https://github.com/ai-forever/Kandinsky-2.git'
# !pip install git+https://github.com/openai/CLIP.git

# %%
from kandinsky2 import get_kandinsky2

# %%
model = get_kandinsky2('cuda', task_type='text2img', cache_dir='/tmp/kandinsky2', model_version='2.1', use_flash_attention=False)

# %%
images = model.generate_text2img('''druids, 4k photo''', num_steps=100,
                          batch_size=1, guidance_scale=4,
                           h=768, w=768
                           ,sampler='p_sampler', prior_cf_scale=4,
                            prior_steps="5",)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=768x768 at 0x7F743AEB62E0>
